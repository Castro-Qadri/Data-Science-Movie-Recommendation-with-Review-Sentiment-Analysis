# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sn

# %%
movies = pd.read_csv("tmdb_5000_movies.csv")
credits = pd.read_csv("tmdb_5000_credits.csv")
# Out:
# Failed to connect to the remote Jupyter Server 'http://localhost:8888/'. Verify the server is running and reachable. (Failed to connect to the remote Jupyter Server 'http://localhost:8888/'. Verify the server is running and reachable. (request to http://localhost:8888/notebooks/Recommendation_System.ipynb/api/kernels?1778329037825 failed, reason: ).).

# %%
movies.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...
#
#                                 production_countries release_date     revenue  \
# 0  [{"iso_3166_1": "US", "name": "United States o...   2009-12-10  2787965087
# 1  [{"iso_3166_1": "US", "name": "United States o...   2007-05-19   961000000
#
#    runtime                                   spoken_languages    status  \
# 0    162.0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1    169.0           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title  vote_average  vote_count
# 0                                    Avatar           7.2       11800
# 1  Pirates of the Caribbean: At World's End           6.9        4500

# %%
credits.head(2)
# Out:
#    movie_id                                     title  \
# 0     19995                                    Avatar
# 1       285  Pirates of the Caribbean: At World's End
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
# concatinate data by id
renamed_credits = credits.rename(columns={"movie_id": "id"})
renamed_credits = renamed_credits.drop(columns=["title"])

# %%
data = movies.merge(renamed_credits, on="id")
data.head(2)
# Out:
#       budget                                             genres  \
# 0  237000000  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  300000000  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                        homepage     id  \
# 0                   http://www.avatarmovie.com/  19995
# 1  http://disney.go.com/disneypictures/pirates/    285
#
#                                             keywords original_language  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...                en
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...                en
#
#                              original_title  \
# 0                                    Avatar
# 1  Pirates of the Caribbean: At World's End
#
#                                             overview  popularity  \
# 0  In the 22nd century, a paraplegic Marine is di...  150.437577
# 1  Captain Barbossa, long believed to be dead, ha...  139.082615
#
#                                 production_companies  ...     revenue runtime  \
# 0  [{"name": "Ingenious Film Partners", "id": 289...  ...  2787965087   162.0
# 1  [{"name": "Walt Disney Pictures", "id": 2}, {"...  ...   961000000   169.0
#
#                                     spoken_languages    status  \
# 0  [{"iso_639_1": "en", "name": "English"}, {"iso...  Released
# 1           [{"iso_639_1": "en", "name": "English"}]  Released
#
#                                           tagline  \
# 0                     Enter the World of Pandora.
# 1  At the end of the world, the adventure begins.
#
#                                       title vote_average vote_count  \
# 0                                    Avatar          7.2      11800
# 1  Pirates of the Caribbean: At World's End          6.9       4500
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
#
# [2 rows x 22 columns]

# %%
movies = data[['id','overview','genres','keywords','title','vote_average','release_date','cast','crew']].copy()
movies.head(2)
# Out:
#       id                                           overview  \
# 0  19995  In the 22nd century, a paraplegic Marine is di...
# 1    285  Captain Barbossa, long believed to be dead, ha...
#
#                                               genres  \
# 0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
#
#                                             keywords  \
# 0  [{"id": 1463, "name": "culture clash"}, {"id":...
# 1  [{"id": 270, "name": "ocean"}, {"id": 726, "na...
#
#                                       title  vote_average release_date  \
# 0                                    Avatar           7.2   2009-12-10
# 1  Pirates of the Caribbean: At World's End           6.9   2007-05-19
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4803 entries, 0 to 4802
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   id            4803 non-null   int64
#  1   overview      4800 non-null   object
#  2   genres        4803 non-null   object
#  3   keywords      4803 non-null   object
#  4   title         4803 non-null   object
#  5   vote_average  4803 non-null   float64
#  6   release_date  4802 non-null   object
#  7   cast          4803 non-null   object
#  8   crew          4803 non-null   object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 337.8+ KB

# %%
movies['release_date'] = movies['release_date'].fillna('N/A')

# %%
movies.duplicated().sum()
# Out:
# 0

# %%
import ast
def convert(obj):
    L = []
    for i in ast.literal_eval(obj):
        L.append(i['name'])
    return L

# %%
movies.loc[:, 'genres'] = movies['genres'].apply(convert)
movies.loc[:,"keywords"] = movies["keywords"].apply(convert)

# %%
movies.head()
# Out:
#        id                                           overview  \
# 0   19995  In the 22nd century, a paraplegic Marine is di...
# 1     285  Captain Barbossa, long believed to be dead, ha...
# 2  206647  A cryptic message from Bond’s past sends him o...
# 3   49026  Following the death of District Attorney Harve...
# 4   49529  John Carter is a war-weary, former military ca...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
# 3               [Action, Crime, Drama, Thriller]
# 4           [Action, Adventure, Science Fiction]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
# 3  [dc comics, crime fighter, terrorist, secret i...
# 4  [based on novel, mars, medallion, space travel...
#
#                                       title  vote_average release_date  \
# 0                                    Avatar           7.2   2009-12-10
# 1  Pirates of the Caribbean: At World's End           6.9   2007-05-19
# 2                                   Spectre           6.3   2015-10-26
# 3                     The Dark Knight Rises           7.6   2012-07-16
# 4                               John Carter           6.1   2012-03-07
#
#                                                 cast  \
# 0  [{"cast_id": 242, "character": "Jake Sully", "...
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...
# 2  [{"cast_id": 1, "character": "James Bond", "cr...
# 3  [{"cast_id": 2, "character": "Bruce Wayne / Ba...
# 4  [{"cast_id": 5, "character": "John Carter", "c...
#
#                                                 crew
# 0  [{"credit_id": "52fe48009251416c750aca23", "de...
# 1  [{"credit_id": "52fe4232c3a36847f800b579", "de...
# 2  [{"credit_id": "54805967c3a36829b5002c41", "de...
# 3  [{"credit_id": "52fe4781c3a36847f81398c3", "de...
# 4  [{"credit_id": "52fe479ac3a36847f813eaa3", "de...

# %%
#extract name from cast
def extract_director(obj):
    L = []
    for i in ast.literal_eval(obj):
        if i['job'] == 'Director':
            L.append(i['name'])
    return L

# %%
movies.loc[:, "crew"] = movies["crew"].apply(extract_director)
movies.head(3)
# Out:
#        id                                           overview  \
# 0   19995  In the 22nd century, a paraplegic Marine is di...
# 1     285  Captain Barbossa, long believed to be dead, ha...
# 2  206647  A cryptic message from Bond’s past sends him o...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
# 2                     [Action, Adventure, Crime]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
# 2  [spy, based on novel, secret agent, sequel, mi...
#
#                                       title  vote_average release_date  \
# 0                                    Avatar           7.2   2009-12-10
# 1  Pirates of the Caribbean: At World's End           6.9   2007-05-19
# 2                                   Spectre           6.3   2015-10-26
#
#                                                 cast              crew
# 0  [{"cast_id": 242, "character": "Jake Sully", "...   [James Cameron]
# 1  [{"cast_id": 4, "character": "Captain Jack Spa...  [Gore Verbinski]
# 2  [{"cast_id": 1, "character": "James Bond", "cr...      [Sam Mendes]

# %%
# extract 4 characters from cast
def extract_name(obj):
    L = []
    counter = 0
    for i in ast.literal_eval(obj):
        if counter != 4:
            L.append(i['name'])
            counter += 1
        else:
            break
    return L

# %%
movies.loc[:, "cast"] = movies["cast"].apply(extract_name)

# %%
movies.head(1)
# Out:
#       id                                           overview  \
# 0  19995  In the 22nd century, a paraplegic Marine is di...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
#
#                                             keywords   title  vote_average  \
# 0  [culture clash, future, space war, space colon...  Avatar           7.2
#
#   release_date                                               cast  \
# 0   2009-12-10  [Sam Worthington, Zoe Saldana, Sigourney Weave...
#
#               crew
# 0  [James Cameron]

# %%
li = [movies["cast"], movies["genres"], movies["keywords"], movies["crew"]]
lam = lambda x:[i.replace(" ","") for i in x]
new_li = []
for i in li:
    i = i.apply(lam)
    new_li.append(i)

movies.loc[:, 'tags'] = new_li[0] + new_li[1] + new_li[2] + new_li[3]

# %%
movies.head(2)
# Out:
#       id                                           overview  \
# 0  19995  In the 22nd century, a paraplegic Marine is di...
# 1    285  Captain Barbossa, long believed to be dead, ha...
#
#                                           genres  \
# 0  [Action, Adventure, Fantasy, Science Fiction]
# 1                   [Adventure, Fantasy, Action]
#
#                                             keywords  \
# 0  [culture clash, future, space war, space colon...
# 1  [ocean, drug abuse, exotic island, east india ...
#
#                                       title  vote_average release_date  \
# 0                                    Avatar           7.2   2009-12-10
# 1  Pirates of the Caribbean: At World's End           6.9   2007-05-19
#
#                                                 cast              crew  \
# 0  [Sam Worthington, Zoe Saldana, Sigourney Weave...   [James Cameron]
# 1  [Johnny Depp, Orlando Bloom, Keira Knightley, ...  [Gore Verbinski]
#
#                                                 tags
# 0  [SamWorthington, ZoeSaldana, SigourneyWeaver, ...
# 1  [JohnnyDepp, OrlandoBloom, KeiraKnightley, Ste...

# %%
movies['tags'].head(2)
# Out:
# 0    [SamWorthington, ZoeSaldana, SigourneyWeaver, ...
# 1    [JohnnyDepp, OrlandoBloom, KeiraKnightley, Ste...
# Name: tags, dtype: object

# %%
def split_overview(x):
    if isinstance(x, str):  # Check if the element is a string
        return x.split()
    else:
        return []

movies.loc[:,"overview"] = movies["overview"].apply(split_overview)

# %%
movies.loc[:, "tags"] = movies["overview"] + movies["tags"]

# %%
movies['tags'].head(2)
# Out:
# 0    [In, the, 22nd, century,, a, paraplegic, Marin...
# 1    [Captain, Barbossa,, long, believed, to, be, d...
# Name: tags, dtype: object

# %%
movies.loc[:, 'tags'] = movies['tags'].apply(lambda x: " ".join(x))
movies.loc[:, 'overview'] = movies['overview'].apply(lambda x: " ".join(x))
movies.loc[:, 'genres'] = movies['genres'].apply(lambda x: ", ".join(x))
movies.loc[:, 'keywords'] = movies['keywords'].apply(lambda x: " ".join(x))
movies.loc[:, 'cast'] = movies['cast'].apply(lambda x: ", ".join(x))
movies.loc[:, 'crew'] = movies['crew'].apply(lambda x: ",  ".join(x))

# %%
movies['tags'][0]
# Out:
# 'In the 22nd century, a paraplegic Marine is dispatched to the moon Pandora on a unique mission, but becomes torn between following orders and protecting an alien civilization. SamWorthington ZoeSaldana SigourneyWeaver StephenLang Action Adventure Fantasy ScienceFiction cultureclash future spacewar spacecolony society spacetravel futuristic romance space alien tribe alienplanet cgi marine soldier battle loveaffair antiwar powerrelations mindandsoul 3d JamesCameron'

# %%
movies.loc[:, "tags"] = movies["tags"].apply(lambda x:x.lower())
movies.head(3)
# Out:
#        id                                           overview  \
# 0   19995  In the 22nd century, a paraplegic Marine is di...
# 1     285  Captain Barbossa, long believed to be dead, ha...
# 2  206647  A cryptic message from Bond’s past sends him o...
#
#                                         genres  \
# 0  Action, Adventure, Fantasy, Science Fiction
# 1                   Adventure, Fantasy, Action
# 2                     Action, Adventure, Crime
#
#                                             keywords  \
# 0  culture clash future space war space colony so...
# 1  ocean drug abuse exotic island east india trad...
# 2  spy based on novel secret agent sequel mi6 bri...
#
#                                       title  vote_average release_date  \
# 0                                    Avatar           7.2   2009-12-10
# 1  Pirates of the Caribbean: At World's End           6.9   2007-05-19
# 2                                   Spectre           6.3   2015-10-26
#
#                                                 cast            crew  \
# 0  Sam Worthington, Zoe Saldana, Sigourney Weaver...   James Cameron
# 1  Johnny Depp, Orlando Bloom, Keira Knightley, S...  Gore Verbinski
# 2  Daniel Craig, Christoph Waltz, Léa Seydoux, Ra...      Sam Mendes
#
#                                                 tags
# 0  in the 22nd century, a paraplegic marine is di...
# 1  captain barbossa, long believed to be dead, ha...
# 2  a cryptic message from bond’s past sends him o...

# %%
#apply stemming
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()
def stem(text):
    y = []
    for i in text.split():
        y.append(ps.stem(i))
    return " ".join(y)

movies.loc[:, "tags"] = movies["tags"].apply(stem)

# %%
movies["tags"][0]
# Out:
# 'in the 22nd century, a parapleg marin is dispatch to the moon pandora on a uniqu mission, but becom torn between follow order and protect an alien civilization. samworthington zoesaldana sigourneyweav stephenlang action adventur fantasi sciencefict cultureclash futur spacewar spacecoloni societi spacetravel futurist romanc space alien tribe alienplanet cgi marin soldier battl loveaffair antiwar powerrel mindandsoul 3d jamescameron'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(stop_words="english", max_features=5000)
vectors = vectorizer.fit_transform(movies["tags"]).toarray()

# %%
vectors.shape
# Out:
# (4803, 5000)

# %%
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vectors)
similarity.shape
# Out:
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# Cell In[32], line 2
#       1 from sklearn.metrics.pairwise import cosine_similarity
# ----> 2 similarity = cosine_similarity(vectors)
#       3 similarity.shape
#
# File E:\111.Semester 6\DS Lab\DS_Project\movie-project\venv\Lib\site-packages\sklearn\utils\_param_validation.py:211, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     205 try:
#     206     with config_context(
#     207         skip_parameter_validation=(
#     208             prefer_skip_nested_validation or global_skip_validation
#     209         )
#     210     ):
# --> 211         return func(*args, **kwargs)
#     212 except InvalidParameterError as e:
#     213     # When the function is just a wrapper around an estimator, we allow
#     214     # the function to delegate validation to the estimator, but we replace
#     215     # the name of the estimator by the name of the function in the error
#     216     # message to avoid confusion.
#     217     msg = re.sub(
#     218         r"parameter of \w+ must be",
#     219         f"parameter of {func.__qualname__} must be",
#     220         str(e),
#     221     )
#
# File E:\111.Semester 6\DS Lab\DS_Project\movie-project\venv\Lib\site-packages\sklearn\metrics\pairwise.py:1579, in cosine_similarity(X, Y, dense_output)
#    1575 # to avoid recursive import
#    1577 X, Y = check_pairwise_arrays(X, Y)
# -> 1579 X_normalized = normalize(X, copy=True)
#    1580 if X is Y:
#    1581     Y_normalized = X_normalized
#
# File E:\111.Semester 6\DS Lab\DS_Project\movie-project\venv\Lib\site-packages\sklearn\utils\_param_validation.py:184, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     182 global_skip_validation = get_config()["skip_parameter_validation"]
#     183 if global_skip_validation:
# --> 184     return func(*args, **kwargs)
#     186 func_sig = signature(func)
#     188 # Map *args/**kwargs to the function signature
#
# File E:\111.Semester 6\DS Lab\DS_Project\movie-project\venv\Lib\site-packages\sklearn\preprocessing\_data.py:1843, in normalize(X, norm, axis, copy, return_norm)
#    1840 else:  # axis == 1:
#    1841     sparse_format = "csr"
# -> 1843 X = check_array(
#    1844     X,
#    1845     accept_sparse=sparse_format,
#    1846     copy=copy,
#    1847     estimator="the normalize function",
#    1848     dtype=FLOAT_DTYPES,
#    1849 )
#    1850 if axis == 0:
#    1851     X = X.T
#
# File E:\111.Semester 6\DS Lab\DS_Project\movie-project\venv\Lib\site-packages\sklearn\utils\validation.py:988, in check_array(array, accept_sparse, accept_large_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, estimator, input_name)
#     985 if _is_numpy_namespace(xp):
#     986     # only make a copy if `array` and `array_orig` may share memory`
#     987     if np.may_share_memory(array, array_orig):
# --> 988         array = _asarray_with_order(
#     989             array, dtype=dtype, order=order, copy=True, xp=xp
#     990         )
#     991 else:
#     992     # always make a copy for non-numpy arrays
#     993     array = _asarray_with_order(
#     994         array, dtype=dtype, order=order, copy=True, xp=xp
#     995     )
#
# File E:\111.Semester 6\DS Lab\DS_Project\movie-project\venv\Lib\site-packages\sklearn\utils\_array_api.py:378, in _asarray_with_order(array, dtype, order, copy, xp)
#     375 if _is_numpy_namespace(xp):
#     376     # Use NumPy API to support order
#     377     if copy is True:
# --> 378         array = numpy.array(array, order=order, dtype=dtype)
#     379     else:
#     380         array = numpy.asarray(array, order=order, dtype=dtype)
#
# MemoryError: Unable to allocate 183. MiB for an array with shape (4803, 5000) and data type float64

# %%
def recommend(movie):
    movie_index = movies[movies['title'] == movie].index[0]
    distances = similarity[movie_index]
    movies_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x:x[1])[1:11]
    for i in movies_list:
        print(movies.iloc[i[0]].title)

# %%
recommend("The Truman Show")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 1
# ----> 1 recommend("The Truman Show")
#
# Cell In[33], line 3, in recommend(movie)
#       1 def recommend(movie):
#       2     movie_index = movies[movies['title'] == movie].index[0]
# ----> 3     distances = similarity[movie_index]
#       4     movies_list = sorted(list(enumerate(distances)), reverse=True, key=lambda x:x[1])[1:11]
#       5     for i in movies_list:
#       6         print(movies.iloc[i[0]].title)
#
# NameError: name 'similarity' is not defined

# %%
import joblib

# %%
joblib.dump(movies.to_dict(), "movies_data.joblib")
# Out:
# ['movies_data.joblib']

# %%
joblib.dump(similarity, "similarity.joblib")
# Out:
# ['similarity.joblib']

# %%
d = joblib.load("Model/movies_data.joblib")

# %%
detail = pd.DataFrame(d)

# %%
detail.head(1)
# Out:
#       id                                           overview  \
# 0  19995  In the 22nd century, a paraplegic Marine is di...
#
#                                         genres  \
# 0  Action, Adventure, Fantasy, Science Fiction
#
#                                             keywords   title  vote_average  \
# 0  culture clash future space war space colony so...  Avatar           7.2
#
#   release_date                                               cast  \
# 0   2009-12-10  Sam Worthington, Zoe Saldana, Sigourney Weaver...
#
#             crew                                               tags
# 0  James Cameron  in the 22nd century, a parapleg marin is dispa...

# %%
li = []
date = detail["release_date"].tolist()

for i in date:
    if i > "2017-01-01":
        li.append(i)
        
li
# Out:
# ['2017-02-03', 'N/A']
